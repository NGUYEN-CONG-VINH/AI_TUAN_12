# %% [markdown]
# <a href="https://colab.research.google.com/github/NGUYEN-CONG-VINH/AI_TUAN_12/blob/main/MTCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Nguyễn Công Vinh 20146183
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 20.6 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN

# %%
filename='/content/drive/MyDrive/colab/hinh/aa.jpg'

# %%
pixels=plt.imread(filename)
detector=MTCNN()
faces=detector.detect_faces(pixels)
for face in faces:
  print(face)
# Out:
# ...
# 2/2 [==============================] - 0s 12ms/step
# {'box': [1131, 128, 113, 132], 'confidence': 0.9999971985816956, 'keypoints': {'left_eye': (1156, 177), 'right_eye': (1204, 180), 'nose': (1171, 205), 'mouth_left': (1157, 228), 'mouth_right': (1199, 232)}}
# {'box': [349, 70, 107, 127], 'confidence': 0.9999313950538635, 'keypoints': {'left_eye': (386, 114), 'right_eye': (433, 116), 'nose': (414, 140), 'mouth_left': (390, 164), 'mouth_right': (430, 164)}}
# {'box': [906, 398, 114, 143], 'confidence': 0.999875545501709, 'keypoints': {'left_eye': (928, 454), 'right_eye': (979, 445), 'nose': (955, 480), 'mouth_left': (940, 507), 'mouth_right': (986, 502)}}
# {'box': [748, 142, 95, 134], 'confidence': 0.9998708963394165, 'keypoints': {'left_eye': (774, 196), 'right_eye': (819, 195), 'nose': (798, 224), 'mouth_left': (776, 242), 'mouth_right': (819, 242)}}
# ...

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
filename='/content/drive/MyDrive/colab/hinh/a1.jpg'
img=plt.imread(filename)
dectector=MTCNN()
faces =detector.detect_faces(img)
plt.imshow(img)
ax=plt.gca()
for face in faces:
  x,y,wight,height=face['box']
  rect=plt.Rectangle((x,y),wight,height,fill=False,color='blue')
  ax.add_patch(rect)#chòng hình lên ảnh
plt.show()
# Out:
# ...
# 11/11 [==============================] - 1s 78ms/step

# %%
plt.savefig('/content/drive/MyDrive/colab/hinh/a2.jpg')

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
filename = '/content/drive/MyDrive/colab/hinh/a1.jpg'
img = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
plt.imshow(img)
ax = plt.gca()
for face in faces:
  x, y , width, height = face['box']
  vect = plt.Rectangle((x, y), width, height, fill = False, color = 'red') #fill = False kh tô hình chử nhật
  ax.add_patch(vect)  # để chồng hình chử nhật lên hình 
  for key, value in face ['keypoints'].items():
    dot = plt.Circle(value, radius = 2, color = 'red')
    ax.add_patch(dot)
plt.show()
# Out:
# ...
# 11/11 [==============================] - 2s 107ms/step

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
matran=[1,2,3,4,5]
def draw_faces(filename,result_list):
  data=plt.imread(filename)
  for i in range(len(result_list)):
    x1,y1,wight,height=result_list[i]['box']
    x2,y2=x1+wight,y1+height
    plt.subplot(1,len(result_list),i+1)
    plt.axis('off')
    plt.imshow(data[y1:y2,x1:x2])
  plt.show()
  for i in range(len(result_list)):
    x1,y1,wight,height=result_list[i]['box']
    x2,y2=x1+wight,y1+height
    #plt.subplot(1,len(result_list),i+1)
    plt.axis('off')
    #plt.imshow(data[y1:y2,x1:x2])
    save='/content/drive/MyDrive/colab/hinh/'+str(i)+'.jpg'
    plt.savefig(save)
filename='/content/drive/MyDrive/colab/hinh/aa.jpg'
img=plt.imread(filename)
detector=MTCNN()
faces=detector.detect_faces(img)
draw_faces(filename,faces)
# Out:
# ...
# 2/2 [==============================] - 0s 10ms/step
